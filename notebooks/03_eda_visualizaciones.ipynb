# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
#Lectura del Dataset

url = 'https://www.dropbox.com/scl/fi/32xdaqm2545076rnbl577/df_final.csv?rlkey=qm00csccin2nr6xwmahwtq4f8&st=zigaetql&dl=1'

df = pd.read_csv(url)
df.head(2)
# Out:
# /tmp/ipykernel_46756/2344250714.py:5: DtypeWarning: Columns (6,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#           id  \
# 0  999980@XC
# 1  999946@XC
#
#                                                        occurrenceID  \
# 0  https://data.biodiversitydata.nl/xeno-canto/observation/XC999980
# 1  https://data.biodiversitydata.nl/xeno-canto/observation/XC999946
#
#   catalogNumber     basisOfRecord           collectionCode  \
# 0      XC999980  HumanObservation  Wildlife sounds - Birds
# 1      XC999946  HumanObservation  Wildlife sounds - Birds
#
#                                                dynamicProperties  \
# 0                            {"recordingDevice":"Tascam DR-05X"}
# 1  {"recordingDevice":"Olympus LS12","microphone":"Primo EM272"}
#
#   otherCatalogNumbers       genus specificEpithet infraspecificEpithet  ...  \
# 0                 NaN    Saxicola        rubicola                  NaN  ...
# 1                 NaN  Haematopus      ostralegus                  NaN  ...
#
#          creator  \
# 0  Colm Philpott
# 1  Paul Coiffard
#
#                                                                                                        accessURI  \
# 0                   https://xeno-canto.org/sounds/uploaded/FIMCRHLLRP/XC999980-17-40-Stonechat%2C-small-road.wav
# 1  https://xeno-canto.org/sounds/uploaded/TLORJJUZZT/XC999946-Huitrier-pie-B-flight-call-20250430_0810-SMDLM.wav
#
#       format  variantLiteral description caption  \
# 0  audio/wav  ac:BestQuality       128 s     NaN
# 1  audio/wav  ac:BestQuality         9 s     NaN
#
#                                                                                                           resourceCreationTechnique  \
# 0  automatic recording: no; bitrate: 1411200 bps; bitrate mode: cbr; audio sampling rate: 44100 Hz; number of channels: 2; lossless
# 1  automatic recording: no; bitrate: 1058400 bps; bitrate mode: cbr; audio sampling rate: 44100 Hz; number of channels: 1; lossless
#
#                 captureDevice  physicalSetting        license_y
# 0             Tascam DR-05X |       Artificial  CC BY-NC-SA 4.0
# 1  Olympus LS12 | Primo EM272          Natural  CC BY-NC-SA 4.0
#
# [2 rows x 53 columns]

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279509 entries, 0 to 279508
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              279509 non-null  object
#  1   occurrenceID                    279509 non-null  object
#  2   catalogNumber                   279509 non-null  object
#  3   basisOfRecord                   279509 non-null  object
#  4   collectionCode                  279509 non-null  object
#  5   dynamicProperties               74871 non-null   object
#  6   otherCatalogNumbers             358 non-null     object
#  7   genus                           279509 non-null  object
#  8   specificEpithet                 279509 non-null  object
#  9   infraspecificEpithet            21846 non-null   object
#  10  scientificName                  279509 non-null  object
#  11  taxonRank                       279509 non-null  object
#  12  kingdom                         279509 non-null  object
#  13  family                          279509 non-null  object
#  14  higherClassification            279509 non-null  object
#  15  nomenclaturalCode               279509 non-null  object
#  16  identificationRemarks           588 non-null     object
#  17  vernacularName                  279509 non-null  object
#  18  longitudeDecimal                279509 non-null  float64
#  19  latitudeDecimal                 279509 non-null  float64
#  20  geodeticDatum                   279509 non-null  object
#  21  country                         279508 non-null  object
#  22  locality                        279505 non-null  object
#  23  verbatimElevation               279509 non-null  object
#  24  recordedBy                      279509 non-null  object
#  25  eventDate                       279171 non-null  object
#  26  eventTime                       265775 non-null  object
#  27  verbatimEventDate               279508 non-null  object
#  28  fieldNotes                      267825 non-null  object
#  29  behavior                        277215 non-null  object
#  30  sex                             101761 non-null  object
#  31  lifeStage                       90658 non-null   object
#  32  preparations                    279360 non-null  object
#  33  references                      279509 non-null  object
#  34  Associated Taxa                 99946 non-null   object
#  35  rightsHolder_x                  279509 non-null  object
#  36  license_x                       279509 non-null  object
#  37  CoreId                          279509 non-null  object
#  38  associatedObservationReference  279509 non-null  object
#  39  Identifier                      279509 non-null  object
#  40  type                            279509 non-null  object
#  41  Rating                          278877 non-null  float64
#  42  rightsHolder_y                  279509 non-null  object
#  43  creator                         279509 non-null  object
#  44  accessURI                       279509 non-null  object
#  45  format                          279509 non-null  object
#  46  variantLiteral                  279509 non-null  object
#  47  description                     279357 non-null  object
#  48  caption                         0 non-null       float64
#  49  resourceCreationTechnique       279509 non-null  object
#  50  captureDevice                   74871 non-null   object
#  51  physicalSetting                 279360 non-null  object
#  52  license_y                       279509 non-null  object
# dtypes: float64(4), object(49)
# memory usage: 113.0+ MB

# %%
df['country'].unique()
# Out:
# array(['Ireland', 'France', 'Spain', 'Ukraine', 'Sweden', 'Germany',
#        'United Kingdom', 'Belgium', 'Netherlands', 'Poland', 'Italy',
#        'Norway', 'Latvia', 'Greece', 'Belarus', 'Denmark', 'Switzerland',
#        'Hungary', 'Bulgaria', 'Russian Federation', 'Romania', 'Turkey',
#        'Finland', 'Croatia', 'Portugal', 'Austria', 'Czech Republic',
#        'Slovenia', 'Slovakia', 'Estonia', 'Bosnia Herzegovina', 'Cyprus',
#        'Andorra', 'Serbia', 'Montenegro', 'Albania', 'Luxembourg',
#        'San Marino', 'Lithuania', 'Macedonia', nan, 'Liechtenstein',
#        'Malta', 'Moldova', 'Monaco'], dtype=object)

# %%
#Duplicados 

# Revisar si hay filas duplicadas completas
duplicados = df.duplicated()
print(duplicados.value_counts())
# Out:
# False    279509
# Name: count, dtype: int64

# %% [markdown]
# Se confirma que el Dataset no tiene duplicados

# %%
#Se confirma que el dataset tiene enlaces de sonidos solamente
print(df['format'].unique())
# Out:
# ['audio/wav' 'audio/mp3']

# %%
pd.set_option('display.max_rows', None)
df['scientificName'].value_counts()
# Out:
# scientificName
# Mystery mystery                        11080
# Parus major                             7100
# Turdus merula                           6853
# Erithacus rubecula                      6101
# Fringilla coelebs                       5767
# Phylloscopus collybita                  4980
# Sylvia atricapilla                      4884
# Turdus philomelos                       4704
# Troglodytes troglodytes                 4336
# Cyanistes caeruleus                     3678
# Emberiza calandra                       3141
# Strix aluco                             3095
# Turdus iliacus                          3086
# Phylloscopus trochilus                  3030
# Emberiza citrinella                     2832
# Rallus aquaticus                        2722
# Corvus cornix cornix                    2711
# Curruca communis                        2705
# Dendrocopos major                       2672
# Loxia curvirostra                       2659
# Luscinia megarhynchos                   2544
# Fulica atra                             2481
# Gallinula chloropus                     2350
# Phylloscopus trochilus trochilus        2341
# Anthus trivialis                        2298
# Periparus ater                          2279
# Numenius arquata                        2272
# Passer domesticus                       2113
# Alauda arvensis                         2091
# Actitis hypoleucos                      2073
# Cettia cetti                            2045
# Acrocephalus palustris                  2002
# Prunella modularis                      1976
# Phylloscopus collybita collybita        1968
# Sitta europaea                          1929
# Garrulus glandarius                     1884
# Ardea cinerea                           1848
# Emberiza hortulana                      1811
# Tringa totanus                          1810
# Fringilla coelebs coelebs               1800
# Cuculus canorus                         1797
# Passer montanus                         1735
# Sylvia borin                            1724
# Chloris chloris                         1721
# Pluvialis apricaria                     1718
# Acrocephalus schoenobaenus              1687
# Acrocephalus scirpaceus                 1674
# Chroicocephalus ridibundus              1651
# Dryocopus martius                       1647
# Carduelis carduelis                     1636
# Curruca communis communis               1632
# Emberiza schoeniclus                    1627
# Regulus regulus                         1625
# Haematopus ostralegus                   1618
# Turdus pilaris                          1568
# Corvus corax                            1561
# Sturnus vulgaris                        1543
# Tachybaptus ruficollis                  1528
# Gallinago gallinago                     1505
# Anthus pratensis                        1493
# Muscicapa striata                       1463
# Hirundo rustica                         1452
# Poecile palustris                       1435
# Phylloscopus sibilatrix                 1432
# Caprimulgus europaeus                   1408
# Tringa nebularia                        1403
# Phoenicurus phoenicurus                 1386
# Athene noctua                           1384
# Certhia familiaris                      1382
# Tringa ochropus                         1363
# Regulus ignicapilla                     1355
# Aegithalos caudatus                     1342
# Linaria cannabina                       1326
# Charadrius dubius                       1320
# Ficedula hypoleuca                      1320
# Oriolus oriolus                         1313
# Turdus merula merula                    1309
# Acrocephalus dumetorum                  1294
# Curruca curruca                         1289
# Coccothraustes coccothraustes           1279
# Motacilla flava                         1279
# Tyto alba                               1278
# Calidris alpina                         1278
# Grus grus                               1267
# Anser anser                             1254
# Vanellus vanellus                       1245
# Hippolais icterina                      1244
# Anas crecca                             1243
# Asio otus                               1238
# Spinus spinus                           1228
# Coturnix coturnix                       1223
# Phoenicurus ochruros                    1221
# Pica pica                               1220
# Turdus viscivorus                       1220
# Charadrius hiaticula                    1199
# Corvus cornix                           1199
# Serinus serinus                         1198
# Certhia brachydactyla                   1154
# Botaurus stellaris                      1142
# Numenius phaeopus                       1133
# Curruca curruca curruca                 1128
# Corvus corone                           1115
# Fringilla montifringilla                1103
# Pyrrhula pyrrhula                       1100
# Picus viridis                           1096
# Coloeus monedula                        1084
# Cyanistes caeruleus obscurus            1077
# Lullula arborea                         1076
# Acrocephalus arundinaceus               1067
# Locustella naevia                       1062
# Curruca melanocephala                   1046
# Turdus torquatus                        1041
# Cygnus cygnus                           1041
# Anas platyrhynchos                      1038
# Tringa glareola                         1014
# Emberiza cirlus                          998
# Nycticorax nycticorax                    992
# Troglodytes troglodytes troglodytes      974
# Poecile montanus                         966
# Motacilla alba                           949
# Ixobrychus minutus                       940
# Buteo buteo                              940
# Alauda arvensis arvensis                 933
# Lophophanes cristatus                    921
# Scolopax rusticola                       904
# Parus major newtoni                      903
# Turdus philomelos clarkei                902
# Hippolais polyglotta                     892
# Loxia pytyopsittacus                     882
# Dryobates minor                          879
# Burhinus oedicnemus                      877
# Porzana porzana                          865
# Mareca penelope                          853
# Streptopelia decaocto                    847
# Sterna hirundo                           839
# Columba palumbus                         838
# Larus argentatus                         834
# Ficedula parva                           831
# Emberiza citrinella citrinella           823
# Delichon urbicum                         817
# Luscinia luscinia                        815
# Crex crex                                806
# Saxicola rubicola                        803
# Emberiza calandra calandra               793
# Corvus frugilegus                        786
# Alcedo atthis                            764
# Phylloscopus bonelli                     756
# Melanitta nigra                          740
# Sylvia atricapilla atricapilla           735
# Phylloscopus ibericus                    732
# Passer montanus montanus                 727
# Glaucidium passerinum                    715
# Cisticola juncidis                       707
# Bubo bubo                                707
# Luscinia svecica                         697
# Dendrocoptes medius                      687
# Lanius collurio                          683
# Apus apus                                683
# Locustella luscinioides                  681
# Aegolius funereus                        677
# Thalasseus sandvicensis                  668
# Locustella fluviatilis                   644
# Himantopus himantopus                    639
# Otus scops                               638
# Picus canus                              619
# Phasianus colchicus                      609
# Saxicola rubetra                         608
# Branta leucopsis                         602
# Motacilla cinerea                        602
# Recurvirostra avosetta                   599
# Cygnus olor                              596
# Phylloscopus inornatus                   590
# Merops apiaster                          585
# Erithacus rubecula melophilus            580
# Larus canus                              571
# Anthus spinoletta                        567
# Pluvialis squatarola                     561
# Jynx torquilla                           546
# Anthus campestris                        535
# Corvus corone corone                     510
# Name: count, dtype: int64

# %%
df['scientificName'].nunique()
#Son 180 especies
# Out:
# 180

# %%
#Ver el url completo para el acceso al trinal del ave

pd.set_option('display.max_colwidth', None) # para que pandas muestre columnas completas

print(df['accessURI'].iloc[0]) #para que muestre valor completo
# Out:
# https://xeno-canto.org/sounds/uploaded/FIMCRHLLRP/XC999980-17-40-Stonechat%2C-small-road.wav

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279509 entries, 0 to 279508
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              279509 non-null  object
#  1   occurrenceID                    279509 non-null  object
#  2   catalogNumber                   279509 non-null  object
#  3   basisOfRecord                   279509 non-null  object
#  4   collectionCode                  279509 non-null  object
#  5   dynamicProperties               74871 non-null   object
#  6   otherCatalogNumbers             358 non-null     object
#  7   genus                           279509 non-null  object
#  8   specificEpithet                 279509 non-null  object
#  9   infraspecificEpithet            21846 non-null   object
#  10  scientificName                  279509 non-null  object
#  11  taxonRank                       279509 non-null  object
#  12  kingdom                         279509 non-null  object
#  13  family                          279509 non-null  object
#  14  higherClassification            279509 non-null  object
#  15  nomenclaturalCode               279509 non-null  object
#  16  identificationRemarks           588 non-null     object
#  17  vernacularName                  279509 non-null  object
#  18  longitudeDecimal                279509 non-null  float64
#  19  latitudeDecimal                 279509 non-null  float64
#  20  geodeticDatum                   279509 non-null  object
#  21  country                         279508 non-null  object
#  22  locality                        279505 non-null  object
#  23  verbatimElevation               279509 non-null  object
#  24  recordedBy                      279509 non-null  object
#  25  eventDate                       279171 non-null  object
#  26  eventTime                       265775 non-null  object
#  27  verbatimEventDate               279508 non-null  object
#  28  fieldNotes                      267825 non-null  object
#  29  behavior                        277215 non-null  object
#  30  sex                             101761 non-null  object
#  31  lifeStage                       90658 non-null   object
#  32  preparations                    279360 non-null  object
#  33  references                      279509 non-null  object
#  34  Associated Taxa                 99946 non-null   object
#  35  rightsHolder_x                  279509 non-null  object
#  36  license_x                       279509 non-null  object
#  37  CoreId                          279509 non-null  object
#  38  associatedObservationReference  279509 non-null  object
#  39  Identifier                      279509 non-null  object
#  40  type                            279509 non-null  object
#  41  Rating                          278877 non-null  float64
#  42  rightsHolder_y                  279509 non-null  object
#  43  creator                         279509 non-null  object
#  44  accessURI                       279509 non-null  object
#  45  format                          279509 non-null  object
#  46  variantLiteral                  279509 non-null  object
#  47  description                     279357 non-null  object
#  48  caption                         0 non-null       float64
#  49  resourceCreationTechnique       279509 non-null  object
#  50  captureDevice                   74871 non-null   object
#  51  physicalSetting                 279360 non-null  object
#  52  license_y                       279509 non-null  object
# dtypes: float64(4), object(49)
# memory usage: 113.0+ MB

# %%
#Seleccion de columnas

df_seleccionado = df[['id', 'vernacularName', 'scientificName', 'genus', 'longitudeDecimal', 'latitudeDecimal', 'infraspecificEpithet', 'family', 'higherClassification', 'description', 'country', 'accessURI']]
df_seleccionado.head()
# Out:
#           id          vernacularName          scientificName         genus  \
# 0  999980@XC      European Stonechat       Saxicola rubicola      Saxicola
# 1  999946@XC  Eurasian Oystercatcher   Haematopus ostralegus    Haematopus
# 2  999938@XC       Common Chiffchaff  Phylloscopus collybita  Phylloscopus
# 3  999936@XC             Song Thrush       Turdus philomelos        Turdus
# 4  999933@XC              Water Rail        Rallus aquaticus        Rallus
#
#    longitudeDecimal  latitudeDecimal infraspecificEpithet          family  \
# 0           -8.4544          51.9535                  NaN    Muscicapidae
# 1            4.4368          43.4558                  NaN  Haematopodidae
# 2           -1.0825          45.8828                  NaN  Phylloscopidae
# 3           -5.0943          48.4641                  NaN        Turdidae
# 4           -8.7475          42.3489                  NaN        Rallidae
#
#                       higherClassification description  country  \
# 0      Animalia|PASSERIFORMES|Muscicapidae       128 s  Ireland
# 1  Animalia|CHARADRIIFORMES|Haematopodidae         9 s   France
# 2    Animalia|PASSERIFORMES|Phylloscopidae        43 s   France
# 3          Animalia|PASSERIFORMES|Turdidae       124 s   France
# 4             Animalia|GRUIFORMES|Rallidae        61 s    Spain
#
#                                                                                                                               accessURI
# 0                                          https://xeno-canto.org/sounds/uploaded/FIMCRHLLRP/XC999980-17-40-Stonechat%2C-small-road.wav
# 1                         https://xeno-canto.org/sounds/uploaded/TLORJJUZZT/XC999946-Huitrier-pie-B-flight-call-20250430_0810-SMDLM.wav
# 2  https://xeno-canto.org/sounds/uploaded/TLORJJUZZT/XC999938-Pouillot-v%C3%A9loce-B-call-sweo-20250203_1530-Route-des-tannes-Moeze.wav
# 3                         https://xeno-canto.org/sounds/uploaded/TLORJJUZZT/XC999936-Grive-musicienne-A-song-20250507_2158-Ouessant.wav
# 4                                          https://xeno-canto.org/sounds/uploaded/RUXVEQZPGU/XC999933-Rallus_aquaticus_250520_0049_.wav

# %% [markdown]
# El Dataset tiene
#
# 1. Paises de Europa
# 2. Nombres de Especies con mas de 500 registros  y 181 tipos de especies
# 3. Solamente filas con archivos de sonidos mp3 o wav
# 4. Tiene 279509 y 12 columnas elegidas

# %% [markdown]
# ANALISIS UNIVARIABLE

# %% [markdown]
# Variables categoricas

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df_seleccionado, x='country', order=df_seleccionado['country'].value_counts().index)
plt.title("Número de registros de aves por país")
plt.xlabel("País")
plt.ylabel("Cantidad de registros")
plt.xticks(rotation=90)  
plt.show()

# %%
# Ver las familias de aves en el dataset 

# Contar cuántos registros hay por familia
family_counts = df_seleccionado['family'].value_counts()

# Crear gráfico de barras vertical
plt.figure(figsize=(12,6))
sns.barplot(x=family_counts.index, y=family_counts.values)
plt.title("Número de registros por familia de aves")
plt.xlabel("Familia")
plt.ylabel("Cantidad de registros")
plt.xticks(rotation=90, fontsize=8)  # rotar nombres para que se vean
plt.show()

# %%
# Aves de acuerdo al genus o Genero

# Contar cuántos registros hay por Genus
genus_counts = df_seleccionado['genus'].value_counts()

# Crear gráfico de barras vertical
plt.figure(figsize=(12,6))
sns.barplot(x=genus_counts.index, y=genus_counts.values)
plt.title("Número de registros por Genero de aves")
plt.xlabel("Genus")
plt.ylabel("Cantidad de registros")
plt.xticks(rotation=90, fontsize=8)  # rotar nombres para que se vean
plt.show()

# %%
# Contar registros por nombre cotidiano o nombre cotidiano
vernacularName_counts = df_seleccionado['vernacularName'].value_counts()

# Gráfico de barras horizontal
plt.figure(figsize=(10,20))  # ancho x alto
sns.barplot(
    x=vernacularName_counts.values,  # cantidad en X
    y=vernacularName_counts.index,   # nombres en Y
    palette="viridis",
)
plt.title("Número de registros por nombre cotidiano de aves", fontsize=14)
plt.xlabel("Cantidad de registros", fontsize=2)
plt.ylabel("Nombre cotidiano (vernacularName)", fontsize=2)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_46756/1157839420.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection=ccrs.PlateCarree())

# Limites de Europa
ax.set_extent([-25, 45, 34, 72], crs=ccrs.PlateCarree())

# Agregar continente y países
ax.add_feature(cfeature.LAND, facecolor='lightgray')
ax.add_feature(cfeature.BORDERS, linewidth=0.5)
ax.add_feature(cfeature.COASTLINE, linewidth=0.5)

# Graficar los puntos de aves
plt.scatter(
    df_seleccionado['longitudeDecimal'],
    df_seleccionado['latitudeDecimal'],
    c='green',
    s=10,
    alpha=0.6,
    transform=ccrs.PlateCarree()
)

plt.title("Distribución de registros de aves en Europa")
plt.show()
